# %% [markdown]
# # 2026-03-20

# %%
print('Hello python')
# Out:
# Hello python

# %% [markdown]
# ## 여기서부터

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('안녕 파이썬')
# Out:
# 안녕 파이썬

# %%
print('ㅎㅇㅎㅇ')
# Out:
# ㅎㅇㅎㅇ

# %%
print('ㅎㅇㅎㅇ')

# %%
print('수정')
# Out:
# 수정
